# %% [markdown]
# ## The plan
#
# Data needed
# 1. 300 postal codes (random)
# 2. All mrt postal codes
# 3. Time taken to travel by direct shuttle from all mrt/bus postal code to Micron
# 4. Time taken without any shuttle by all postal codes
# 5. One bus carry 10 people, will increase to 40
#
# How to get time taken by no shuttle:
# Google Maps distance matrix api with transit as the option
# Generate halfway point -> Whether they take the MRT
#
# How to get driving time
# Google maps distance matrix api, measure driving time with traffic in the morning and evening

# %% [markdown]
# ## 2 choices
#
# Either model the whole MRT map into a graph problem
# Or model the whole MRT and bus stop map into a graph problem (A lot more complicated)
#
# Small problem first
#
# We want to move everyone from any mrt station to marsiling -> Which place have enough demand to create a new more direct route

# %%
class Vertex:
    def __init__(self, node):
        self.id = node
        self.adjacent = {}
        # Set distance to infinity for all nodes
        self.distance = 10000000000000
        # Mark all nodes unvisited        
        self.visited = False  
        # Predecessor
        self.previous = None

    def add_neighbor(self, neighbor, weight=0):
        self.adjacent[neighbor] = weight

    def get_connections(self):
        return self.adjacent.keys()  

    def get_id(self):
        return self.id

    def get_weight(self, neighbor):
        return self.adjacent[neighbor]

    def set_distance(self, dist):
        self.distance = dist

    def get_distance(self):
        return self.distance

    def set_previous(self, prev):
        self.previous = prev

    def set_visited(self):
        self.visited = True

    def __str__(self):
        return str(self.id) + ' adjacent: ' + str([x.id for x in self.adjacent])
    
    def __lt__(self, other):
        return self.get_distance() < other.get_distance()
    
    def __le__(self,other):
        return self.get_distance() <= other.get_distance()
    
    def __gt__(self,other):
        return self.get_distance() > other.get_distance()
    
    def __ge__(self,other):
        return self.get_distance() >= other.get_distance()

class Graph:
    def __init__(self):
        self.vert_dict = {}
        self.num_vertices = 0

    def __iter__(self):
        return iter(self.vert_dict.values())

    def add_vertex(self, node):
        self.num_vertices = self.num_vertices + 1
        new_vertex = Vertex(node)
        self.vert_dict[node] = new_vertex
        return new_vertex

    def get_vertex(self, n):
        if n in self.vert_dict:
            return self.vert_dict[n]
        else:
            return None

    def add_edge(self, frm, to, cost = 0):
        if frm not in self.vert_dict:
            self.add_vertex(frm)
        if to not in self.vert_dict:
            self.add_vertex(to)

        self.vert_dict[frm].add_neighbor(self.vert_dict[to], cost)
        self.vert_dict[to].add_neighbor(self.vert_dict[frm], cost)

    def get_vertices(self):
        return self.vert_dict.keys()

    def set_previous(self, current):
        self.previous = current

    def get_previous(self, current):
        return self.previous
    
def add_vertex_mrt_line(line_name, line_start, line_end, graph):
    for i in range(line_start,line_end+1):
        graph.add_vertex(line_name + str(i))
    return graph

def add_mrt_stations(g):
    # Add NS Line
    g = add_vertex_mrt_line("NS", 1, 28, g)
    # Add TE Line
    g = add_vertex_mrt_line("TE", 1, 9, g)
    # Add DT Line
    g = add_vertex_mrt_line("DT", 1, 35, g)
    # Add EW Line
    g = add_vertex_mrt_line("EW", 1, 33, g)
    # Add EWEXT Line
    g = add_vertex_mrt_line("CG", 1, 2, g)
    # Add CC Line
    g = add_vertex_mrt_line("CC", 1, 29, g)
    # Add CC Line Ext
    g = add_vertex_mrt_line("CC", 33, 34, g)
    # Add NE Line
    g = add_vertex_mrt_line("NE", 1, 17, g)
    
    # Add BPLRT Line
    g = add_vertex_mrt_line("BP", 1, 13, g)
    # Add SKLRTE Line
    g = add_vertex_mrt_line("SE", 1, 5, g)
    # Add SKLRTW Line
    g = add_vertex_mrt_line("SW", 1, 8, g)
    # Add PLRTE Line
    g = add_vertex_mrt_line("PE", 1, 7, g)
    # Add PLRTW Line
    g = add_vertex_mrt_line("PW", 1, 7, g)
    
    return g
    

def add_edge_mrt_line(line_name,start, end, g):
    #this assumes 1->2->3 etc and every station 2.5 min
    for i in range(start, end):
        g.add_edge(line_name + str(i), line_name + str(i+1), 2.5)
    return g
        
def add_traditional_station_connection(g):
    # Add NS Line
    g = add_edge_mrt_line("NS", 1, 28, g)
    # Add TE Line
    g = add_edge_mrt_line("TE", 1, 9, g)
    # Add DT Line
    g = add_edge_mrt_line("DT", 1, 35, g)
    # Add EW Line
    g = add_edge_mrt_line("EW", 1, 33, g)
    # Add EWEXT Line
    g = add_edge_mrt_line("CG", 0, 2, g)
    # Add CC Line
    g = add_edge_mrt_line("CC", 1, 29, g)
    # Add CC Line Ext
    g = add_edge_mrt_line("CC", 33, 34, g)
    # Add NE Line
    g = add_edge_mrt_line("NE", 1, 17, g)
    
    # Add BPLRT Line
    g = add_edge_mrt_line("BP", 1, 13, g)
    # Add SKLRTE Line
    g = add_edge_mrt_line("SE", 1, 5, g)
    # Add SKLRTW Line
    g = add_edge_mrt_line("SW", 1, 8, g)
    # Add PLRTE Line
    g = add_edge_mrt_line("PE", 1, 7, g)
    # Add PLRTW Line
    g = add_edge_mrt_line("PW", 1, 7, g)
    return g
    
def add_custom_edge(g, station_a, station_b, connection_time):
    #assuming connection time is 3 min
    g.add_edge(station_a, station_b, connection_time)
    return g
    
if __name__ == '__main__':

    g = Graph()
    
    #add all mrt stations
    g = add_mrt_stations(g)
    
    #add all traditional connections
    g = add_traditional_station_connection(g)

    #add custom edge (Interchanges and missed out loops)
    g = add_custom_edge(g,'EW24', 'NS1', 1) #jurong east
    g = add_custom_edge(g,'BP1', 'NS4', 3) #CCK
    g = add_custom_edge(g,'BP6', 'DT1', 3) #BP
    g = add_custom_edge(g,'BP6', 'BP13', 2.5) #loop BPLRT
    g = add_custom_edge(g,'NS9', 'TE2', 3) #WOODLANDS
    g = add_custom_edge(g,'CC17', 'TE9', 3) #Caldecott
    g = add_custom_edge(g,'NS17', 'CC15', 3) #Bishan
    g = add_custom_edge(g,'NS21', 'DT11', 3) #Newton
    g = add_custom_edge(g,'CC19', 'DT9', 3) #Botanic gardens
    g = add_custom_edge(g,'CC22', 'EW21', 3) #bouna vista
    g = add_custom_edge(g,'CC29', 'NE1', 3) #Harbourfront
    g = add_custom_edge(g,'EW16', 'NE3', 3) #Outram park
    g = add_custom_edge(g,'NE4', 'DT19', 3) #Chinatown
    g = add_custom_edge(g,'NS24', 'NE6', 3) #Dohby
    g = add_custom_edge(g,'NS24', 'CC1', 3) #Dohby
    g = add_custom_edge(g,'CC1', 'NE6', 3) #Dohby
    g = add_custom_edge(g,'DT12', 'NE7', 3) #Little India
    g = add_custom_edge(g,'NS25', 'EW13', 1) #City Hall
    g = add_custom_edge(g,'NS26', 'EW14', 1) #Raffles Place
    g = add_custom_edge(g,'EW12', 'DT14', 3) #Bugis
    g = add_custom_edge(g,'NE12', 'CC13', 3) #Serangoon
    g = add_custom_edge(g,'SW8', 'NE16', 3.5) #Sengkang LRT
    g = add_custom_edge(g,'SW1', 'NE16', 3.5) #Sengkang LRT
    g = add_custom_edge(g,'SW8', 'NE16', 3.5) #Sengkang LRT
    g = add_custom_edge(g,'SE1', 'NE16', 3.5) #Sengkang LRT
    g = add_custom_edge(g,'PW7', 'NE17', 3.5) #Punggol LRT
    g = add_custom_edge(g,'PW1', 'NE17', 3.5) #Punggol LRT
    g = add_custom_edge(g,'PE7', 'NE17', 3.5) #Punggol LRT
    g = add_custom_edge(g,'PE1', 'NE17', 3.5) #Punggol LRT
    g = add_custom_edge(g,'CC10', 'DT26', 3) #Macpherson
    g = add_custom_edge(g,'EW8', 'CC9', 3) #Paya Lebar
    g = add_custom_edge(g,'DT15', 'CC4', 2) #Promenade
    g = add_custom_edge(g,'CC4', 'CC34', 1.5) #Promenade - Bayfront
    g = add_custom_edge(g,'DT16', 'CC34', 2) #Bayfront
    g = add_custom_edge(g,'NS27', 'CC33', 3) #Marina Bay
    g = add_custom_edge(g,'EW2', 'DT32', 3) #Tampines
    g = add_custom_edge(g,'EW4', 'CG0', 1) #Tanah
    g = add_custom_edge(g,'DT35', 'CG1', 3) #Expo

    for v in g:
        for w in v.get_connections():
            vid = v.get_id()
            wid = w.get_id()
            print ('( %s , %s, %3d)'  % ( vid, wid, v.get_weight(w)))

    for v in g:
        print ('g.vert_dict[%s]=%s' %(v.get_id(), g.vert_dict[v.get_id()]))
# Out:
# ( NS1 , NS2,   2)
# ( NS1 , EW24,   1)
# ( NS2 , NS1,   2)
# ( NS2 , NS3,   2)
# ( NS3 , NS2,   2)
# ( NS3 , NS4,   2)
# ( NS4 , NS3,   2)
# ( NS4 , NS5,   2)
# ( NS4 , BP1,   3)
# ( NS5 , NS4,   2)
# ( NS5 , NS6,   2)
# ( NS6 , NS5,   2)
# ( NS6 , NS7,   2)
# ( NS7 , NS6,   2)
# ( NS7 , NS8,   2)
# ( NS8 , NS7,   2)
# ( NS8 , NS9,   2)
# ( NS9 , NS8,   2)
# ( NS9 , NS10,   2)
# ( NS9 , TE2,   3)
# ( NS10 , NS9,   2)
# ( NS10 , NS11,   2)
# ( NS11 , NS10,   2)
# ( NS11 , NS12,   2)
# ( NS12 , NS11,   2)
# ( NS12 , NS13,   2)
# ( NS13 , NS12,   2)
# ( NS13 , NS14,   2)
# ( NS14 , NS13,   2)
# ( NS14 , NS15,   2)
# ( NS15 , NS14,   2)
# ( NS15 , NS16,   2)
# ( NS16 , NS15,   2)
# ( NS16 , NS17,   2)
# ( NS17 , NS16,   2)
# ( NS17 , NS18,   2)
# ( NS17 , CC15,   3)
# ( NS18 , NS17,   2)
# ( NS18 , NS19,   2)
# ( NS19 , NS18,   2)
# ( NS19 , NS20,   2)
# ( NS20 , NS19,   2)
# ( NS20 , NS21,   2)
# ( NS21 , NS20,   2)
# ( NS21 , NS22,   2)
# ( NS21 , DT11,   3)
# ( NS22 , NS21,   2)
# ( NS22 , NS23,   2)
# ( NS23 , NS22,   2)
# ( NS23 , NS24,   2)
# ( NS24 , NS23,   2)
# ( NS24 , NS25,   2)
# ( NS24 , NE6,   3)
# ( NS24 , CC1,   3)
# ( NS25 , NS24,   2)
# ( NS25 , NS26,   2)
# ( NS25 , EW13,   1)
# ( NS26 , NS25,   2)
# ( NS26 , NS27,   2)
# ( NS26 , EW14,   1)
# ( NS27 , NS26,   2)
# ( NS27 , NS28,   2)
# ( NS27 , CC33,   3)
# ( NS28 , NS27,   2)
# ( TE1 , TE2,   2)
# ( TE2 , TE1,   2)
# ( TE2 , TE3,   2)
# ( TE2 , NS9,   3)
# ( TE3 , TE2,   2)
# ( TE3 , TE4,   2)
# ( TE4 , TE3,   2)
# ( TE4 , TE5,   2)
# ( TE5 , TE4,   2)
# ( TE5 , TE6,   2)
# ( TE6 , TE5,   2)
# ( TE6 , TE7,   2)
# ( TE7 , TE6,   2)
# ( TE7 , TE8,   2)
# ( TE8 , TE7,   2)
# ( TE8 , TE9,   2)
# ( TE9 , TE8,   2)
# ( TE9 , CC17,   3)
# ( DT1 , DT2,   2)
# ( DT1 , BP6,   3)
# ( DT2 , DT1,   2)
# ( DT2 , DT3,   2)
# ( DT3 , DT2,   2)
# ( DT3 , DT4,   2)
# ( DT4 , DT3,   2)
# ( DT4 , DT5,   2)
# ( DT5 , DT4,   2)
# ( DT5 , DT6,   2)
# ( DT6 , DT5,   2)
# ( DT6 , DT7,   2)
# ( DT7 , DT6,   2)
# ( DT7 , DT8,   2)
# ( DT8 , DT7,   2)
# ( DT8 , DT9,   2)
# ( DT9 , DT8,   2)
# ( DT9 , DT10,   2)
# ( DT9 , CC19,   3)
# ( DT10 , DT9,   2)
# ( DT10 , DT11,   2)
# ( DT11 , DT10,   2)
# ( DT11 , DT12,   2)
# ( DT11 , NS21,   3)
# ( DT12 , DT11,   2)
# ( DT12 , DT13,   2)
# ( DT12 , NE7,   3)
# ( DT13 , DT12,   2)
# ( DT13 , DT14,   2)
# ( DT14 , DT13,   2)
# ( DT14 , DT15,   2)
# ( DT14 , EW12,   3)
# ( DT15 , DT14,   2)
# ( DT15 , DT16,   2)
# ( DT15 , CC4,   2)
# ( DT16 , DT15,   2)
# ( DT16 , DT17,   2)
# ( DT16 , CC34,   2)
# ( DT17 , DT16,   2)
# ( DT17 , DT18,   2)
# ( DT18 , DT17,   2)
# ( DT18 , DT19,   2)
# ( DT19 , DT18,   2)
# ( DT19 , DT20,   2)
# ( DT19 , NE4,   3)
# ( DT20 , DT19,   2)
# ( DT20 , DT21,   2)
# ( DT21 , DT20,   2)
# ( DT21 , DT22,   2)
# ( DT22 , DT21,   2)
# ( DT22 , DT23,   2)
# ( DT23 , DT22,   2)
# ( DT23 , DT24,   2)
# ( DT24 , DT23,   2)
# ( DT24 , DT25,   2)
# ( DT25 , DT24,   2)
# ( DT25 , DT26,   2)
# ( DT26 , DT25,   2)
# ( DT26 , DT27,   2)
# ( DT26 , CC10,   3)
# ( DT27 , DT26,   2)
# ( DT27 , DT28,   2)
# ( DT28 , DT27,   2)
# ( DT28 , DT29,   2)
# ( DT29 , DT28,   2)
# ( DT29 , DT30,   2)
# ( DT30 , DT29,   2)
# ( DT30 , DT31,   2)
# ( DT31 , DT30,   2)
# ( DT31 , DT32,   2)
# ( DT32 , DT31,   2)
# ( DT32 , DT33,   2)
# ( DT32 , EW2,   3)
# ( DT33 , DT32,   2)
# ( DT33 , DT34,   2)
# ( DT34 , DT33,   2)
# ( DT34 , DT35,   2)
# ( DT35 , DT34,   2)
# ( DT35 , CG1,   3)
# ( EW1 , EW2,   2)
# ( EW2 , EW1,   2)
# ( EW2 , EW3,   2)
# ( EW2 , DT32,   3)
# ( EW3 , EW2,   2)
# ( EW3 , EW4,   2)
# ( EW4 , EW3,   2)
# ( EW4 , EW5,   2)
# ( EW4 , CG0,   1)
# ( EW5 , EW4,   2)
# ( EW5 , EW6,   2)
# ( EW6 , EW5,   2)
# ( EW6 , EW7,   2)
# ( EW7 , EW6,   2)
# ( EW7 , EW8,   2)
# ( EW8 , EW7,   2)
# ( EW8 , EW9,   2)
# ( EW8 , CC9,   3)
# ( EW9 , EW8,   2)
# ( EW9 , EW10,   2)
# ( EW10 , EW9,   2)
# ( EW10 , EW11,   2)
# ( EW11 , EW10,   2)
# ( EW11 , EW12,   2)
# ( EW12 , EW11,   2)
# ( EW12 , EW13,   2)
# ( EW12 , DT14,   3)
# ( EW13 , EW12,   2)
# ( EW13 , EW14,   2)
# ( EW13 , NS25,   1)
# ( EW14 , EW13,   2)
# ( EW14 , EW15,   2)
# ( EW14 , NS26,   1)
# ( EW15 , EW14,   2)
# ( EW15 , EW16,   2)
# ( EW16 , EW15,   2)
# ( EW16 , EW17,   2)
# ( EW16 , NE3,   3)
# ( EW17 , EW16,   2)
# ( EW17 , EW18,   2)
# ( EW18 , EW17,   2)
# ( EW18 , EW19,   2)
# ( EW19 , EW18,   2)
# ( EW19 , EW20,   2)
# ( EW20 , EW19,   2)
# ( EW20 , EW21,   2)
# ( EW21 , EW20,   2)
# ( EW21 , EW22,   2)
# ( EW21 , CC22,   3)
# ( EW22 , EW21,   2)
# ( EW22 , EW23,   2)
# ( EW23 , EW22,   2)
# ( EW23 , EW24,   2)
# ( EW24 , EW23,   2)
# ( EW24 , EW25,   2)
# ( EW24 , NS1,   1)
# ( EW25 , EW24,   2)
# ( EW25 , EW26,   2)
# ( EW26 , EW25,   2)
# ( EW26 , EW27,   2)
# ( EW27 , EW26,   2)
# ( EW27 , EW28,   2)
# ( EW28 , EW27,   2)
# ( EW28 , EW29,   2)
# ( EW29 , EW28,   2)
# ( EW29 , EW30,   2)
# ( EW30 , EW29,   2)
# ( EW30 , EW31,   2)
# ( EW31 , EW30,   2)
# ( EW31 , EW32,   2)
# ( EW32 , EW31,   2)
# ( EW32 , EW33,   2)
# ( EW33 , EW32,   2)
# ( CG1 , CG0,   2)
# ( CG1 , CG2,   2)
# ( CG1 , DT35,   3)
# ( CG2 , CG1,   2)
# ( CC1 , CC2,   2)
# ( CC1 , NS24,   3)
# ( CC1 , NE6,   3)
# ( CC2 , CC1,   2)
# ( CC2 , CC3,   2)
# ( CC3 , CC2,   2)
# ( CC3 , CC4,   2)
# ( CC4 , CC3,   2)
# ( CC4 , CC5,   2)
# ( CC4 , DT15,   2)
# ( CC4 , CC34,   1)
# ( CC5 , CC4,   2)
# ( CC5 , CC6,   2)
# ( CC6 , CC5,   2)
# ( CC6 , CC7,   2)
# ( CC7 , CC6,   2)
# ( CC7 , CC8,   2)
# ( CC8 , CC7,   2)
# ( CC8 , CC9,   2)
# ( CC9 , CC8,   2)
# ( CC9 , CC10,   2)
# ( CC9 , EW8,   3)
# ( CC10 , CC9,   2)
# ( CC10 , CC11,   2)
# ( CC10 , DT26,   3)
# ( CC11 , CC10,   2)
# ( CC11 , CC12,   2)
# ( CC12 , CC11,   2)
# ( CC12 , CC13,   2)
# ( CC13 , CC12,   2)
# ( CC13 , CC14,   2)
# ( CC13 , NE12,   3)
# ( CC14 , CC13,   2)
# ( CC14 , CC15,   2)
# ( CC15 , CC14,   2)
# ( CC15 , CC16,   2)
# ( CC15 , NS17,   3)
# ( CC16 , CC15,   2)
# ( CC16 , CC17,   2)
# ( CC17 , CC16,   2)
# ( CC17 , CC18,   2)
# ( CC17 , TE9,   3)
# ( CC18 , CC17,   2)
# ( CC18 , CC19,   2)
# ( CC19 , CC18,   2)
# ( CC19 , CC20,   2)
# ( CC19 , DT9,   3)
# ( CC20 , CC19,   2)
# ( CC20 , CC21,   2)
# ( CC21 , CC20,   2)
# ( CC21 , CC22,   2)
# ( CC22 , CC21,   2)
# ( CC22 , CC23,   2)
# ( CC22 , EW21,   3)
# ( CC23 , CC22,   2)
# ( CC23 , CC24,   2)
# ( CC24 , CC23,   2)
# ( CC24 , CC25,   2)
# ( CC25 , CC24,   2)
# ( CC25 , CC26,   2)
# ( CC26 , CC25,   2)
# ( CC26 , CC27,   2)
# ( CC27 , CC26,   2)
# ( CC27 , CC28,   2)
# ( CC28 , CC27,   2)
# ( CC28 , CC29,   2)
# ( CC29 , CC28,   2)
# ( CC29 , NE1,   3)
# ( CC33 , CC34,   2)
# ( CC33 , NS27,   3)
# ( CC34 , CC33,   2)
# ( CC34 , CC4,   1)
# ( CC34 , DT16,   2)
# ( NE1 , NE2,   2)
# ( NE1 , CC29,   3)
# ( NE2 , NE1,   2)
# ( NE2 , NE3,   2)
# ( NE3 , NE2,   2)
# ( NE3 , NE4,   2)
# ( NE3 , EW16,   3)
# ( NE4 , NE3,   2)
# ( NE4 , NE5,   2)
# ( NE4 , DT19,   3)
# ( NE5 , NE4,   2)
# ( NE5 , NE6,   2)
# ( NE6 , NE5,   2)
# ( NE6 , NE7,   2)
# ( NE6 , NS24,   3)
# ( NE6 , CC1,   3)
# ( NE7 , NE6,   2)
# ( NE7 , NE8,   2)
# ( NE7 , DT12,   3)
# ( NE8 , NE7,   2)
# ( NE8 , NE9,   2)
# ( NE9 , NE8,   2)
# ( NE9 , NE10,   2)
# ( NE10 , NE9,   2)
# ( NE10 , NE11,   2)
# ( NE11 , NE10,   2)
# ( NE11 , NE12,   2)
# ( NE12 , NE11,   2)
# ( NE12 , NE13,   2)
# ( NE12 , CC13,   3)
# ( NE13 , NE12,   2)
# ( NE13 , NE14,   2)
# ( NE14 , NE13,   2)
# ( NE14 , NE15,   2)
# ( NE15 , NE14,   2)
# ( NE15 , NE16,   2)
# ( NE16 , NE15,   2)
# ( NE16 , NE17,   2)
# ( NE16 , SW8,   3)
# ( NE16 , SW1,   3)
# ( NE16 , SE1,   3)
# ( NE17 , NE16,   2)
# ( NE17 , PW7,   3)
# ( NE17 , PW1,   3)
# ( NE17 , PE7,   3)
# ( NE17 , PE1,   3)
# ( BP1 , BP2,   2)
# ( BP1 , NS4,   3)
# ( BP2 , BP1,   2)
# ( BP2 , BP3,   2)
# ( BP3 , BP2,   2)
# ( BP3 , BP4,   2)
# ( BP4 , BP3,   2)
# ( BP4 , BP5,   2)
# ( BP5 , BP4,   2)
# ( BP5 , BP6,   2)
# ( BP6 , BP5,   2)
# ( BP6 , BP7,   2)
# ( BP6 , DT1,   3)
# ( BP6 , BP13,   2)
# ( BP7 , BP6,   2)
# ( BP7 , BP8,   2)
# ( BP8 , BP7,   2)
# ( BP8 , BP9,   2)
# ( BP9 , BP8,   2)
# ( BP9 , BP10,   2)
# ( BP10 , BP9,   2)
# ( BP10 , BP11,   2)
# ( BP11 , BP10,   2)
# ( BP11 , BP12,   2)
# ( BP12 , BP11,   2)
# ( BP12 , BP13,   2)
# ( BP13 , BP12,   2)
# ( BP13 , BP6,   2)
# ( SE1 , SE2,   2)
# ( SE1 , NE16,   3)
# ( SE2 , SE1,   2)
# ( SE2 , SE3,   2)
# ( SE3 , SE2,   2)
# ( SE3 , SE4,   2)
# ( SE4 , SE3,   2)
# ( SE4 , SE5,   2)
# ( SE5 , SE4,   2)
# ( SW1 , SW2,   2)
# ( SW1 , NE16,   3)
# ( SW2 , SW1,   2)
# ( SW2 , SW3,   2)
# ( SW3 , SW2,   2)
# ( SW3 , SW4,   2)
# ( SW4 , SW3,   2)
# ( SW4 , SW5,   2)
# ( SW5 , SW4,   2)
# ( SW5 , SW6,   2)
# ( SW6 , SW5,   2)
# ( SW6 , SW7,   2)
# ( SW7 , SW6,   2)
# ( SW7 , SW8,   2)
# ( SW8 , SW7,   2)
# ( SW8 , NE16,   3)
# ( PE1 , PE2,   2)
# ( PE1 , NE17,   3)
# ( PE2 , PE1,   2)
# ( PE2 , PE3,   2)
# ( PE3 , PE2,   2)
# ( PE3 , PE4,   2)
# ( PE4 , PE3,   2)
# ( PE4 , PE5,   2)
# ( PE5 , PE4,   2)
# ( PE5 , PE6,   2)
# ( PE6 , PE5,   2)
# ( PE6 , PE7,   2)
# ( PE7 , PE6,   2)
# ( PE7 , NE17,   3)
# ( PW1 , PW2,   2)
# ( PW1 , NE17,   3)
# ( PW2 , PW1,   2)
# ( PW2 , PW3,   2)
# ( PW3 , PW2,   2)
# ( PW3 , PW4,   2)
# ( PW4 , PW3,   2)
# ( PW4 , PW5,   2)
# ( PW5 , PW4,   2)
# ( PW5 , PW6,   2)
# ( PW6 , PW5,   2)
# ( PW6 , PW7,   2)
# ( PW7 , PW6,   2)
# ( PW7 , NE17,   3)
# ( CG0 , CG1,   2)
# ( CG0 , EW4,   1)
# g.vert_dict[NS1]=NS1 adjacent: ['NS2', 'EW24']
# g.vert_dict[NS2]=NS2 adjacent: ['NS1', 'NS3']
# g.vert_dict[NS3]=NS3 adjacent: ['NS2', 'NS4']
# g.vert_dict[NS4]=NS4 adjacent: ['NS3', 'NS5', 'BP1']
# g.vert_dict[NS5]=NS5 adjacent: ['NS4', 'NS6']
# g.vert_dict[NS6]=NS6 adjacent: ['NS5', 'NS7']
# g.vert_dict[NS7]=NS7 adjacent: ['NS6', 'NS8']
# g.vert_dict[NS8]=NS8 adjacent: ['NS7', 'NS9']
# g.vert_dict[NS9]=NS9 adjacent: ['NS8', 'NS10', 'TE2']
# g.vert_dict[NS10]=NS10 adjacent: ['NS9', 'NS11']
# g.vert_dict[NS11]=NS11 adjacent: ['NS10', 'NS12']
# g.vert_dict[NS12]=NS12 adjacent: ['NS11', 'NS13']
# g.vert_dict[NS13]=NS13 adjacent: ['NS12', 'NS14']
# g.vert_dict[NS14]=NS14 adjacent: ['NS13', 'NS15']
# g.vert_dict[NS15]=NS15 adjacent: ['NS14', 'NS16']
# g.vert_dict[NS16]=NS16 adjacent: ['NS15', 'NS17']
# g.vert_dict[NS17]=NS17 adjacent: ['NS16', 'NS18', 'CC15']
# g.vert_dict[NS18]=NS18 adjacent: ['NS17', 'NS19']
# g.vert_dict[NS19]=NS19 adjacent: ['NS18', 'NS20']
# g.vert_dict[NS20]=NS20 adjacent: ['NS19', 'NS21']
# g.vert_dict[NS21]=NS21 adjacent: ['NS20', 'NS22', 'DT11']
# g.vert_dict[NS22]=NS22 adjacent: ['NS21', 'NS23']
# g.vert_dict[NS23]=NS23 adjacent: ['NS22', 'NS24']
# g.vert_dict[NS24]=NS24 adjacent: ['NS23', 'NS25', 'NE6', 'CC1']
# g.vert_dict[NS25]=NS25 adjacent: ['NS24', 'NS26', 'EW13']
# g.vert_dict[NS26]=NS26 adjacent: ['NS25', 'NS27', 'EW14']
# g.vert_dict[NS27]=NS27 adjacent: ['NS26', 'NS28', 'CC33']
# g.vert_dict[NS28]=NS28 adjacent: ['NS27']
# g.vert_dict[TE1]=TE1 adjacent: ['TE2']
# g.vert_dict[TE2]=TE2 adjacent: ['TE1', 'TE3', 'NS9']
# g.vert_dict[TE3]=TE3 adjacent: ['TE2', 'TE4']
# g.vert_dict[TE4]=TE4 adjacent: ['TE3', 'TE5']
# g.vert_dict[TE5]=TE5 adjacent: ['TE4', 'TE6']
# g.vert_dict[TE6]=TE6 adjacent: ['TE5', 'TE7']
# g.vert_dict[TE7]=TE7 adjacent: ['TE6', 'TE8']
# g.vert_dict[TE8]=TE8 adjacent: ['TE7', 'TE9']
# g.vert_dict[TE9]=TE9 adjacent: ['TE8', 'CC17']
# g.vert_dict[DT1]=DT1 adjacent: ['DT2', 'BP6']
# g.vert_dict[DT2]=DT2 adjacent: ['DT1', 'DT3']
# g.vert_dict[DT3]=DT3 adjacent: ['DT2', 'DT4']
# g.vert_dict[DT4]=DT4 adjacent: ['DT3', 'DT5']
# g.vert_dict[DT5]=DT5 adjacent: ['DT4', 'DT6']
# g.vert_dict[DT6]=DT6 adjacent: ['DT5', 'DT7']
# g.vert_dict[DT7]=DT7 adjacent: ['DT6', 'DT8']
# g.vert_dict[DT8]=DT8 adjacent: ['DT7', 'DT9']
# g.vert_dict[DT9]=DT9 adjacent: ['DT8', 'DT10', 'CC19']
# g.vert_dict[DT10]=DT10 adjacent: ['DT9', 'DT11']
# g.vert_dict[DT11]=DT11 adjacent: ['DT10', 'DT12', 'NS21']
# g.vert_dict[DT12]=DT12 adjacent: ['DT11', 'DT13', 'NE7']
# g.vert_dict[DT13]=DT13 adjacent: ['DT12', 'DT14']
# g.vert_dict[DT14]=DT14 adjacent: ['DT13', 'DT15', 'EW12']
# g.vert_dict[DT15]=DT15 adjacent: ['DT14', 'DT16', 'CC4']
# g.vert_dict[DT16]=DT16 adjacent: ['DT15', 'DT17', 'CC34']
# g.vert_dict[DT17]=DT17 adjacent: ['DT16', 'DT18']
# g.vert_dict[DT18]=DT18 adjacent: ['DT17', 'DT19']
# g.vert_dict[DT19]=DT19 adjacent: ['DT18', 'DT20', 'NE4']
# g.vert_dict[DT20]=DT20 adjacent: ['DT19', 'DT21']
# g.vert_dict[DT21]=DT21 adjacent: ['DT20', 'DT22']
# g.vert_dict[DT22]=DT22 adjacent: ['DT21', 'DT23']
# g.vert_dict[DT23]=DT23 adjacent: ['DT22', 'DT24']
# g.vert_dict[DT24]=DT24 adjacent: ['DT23', 'DT25']
# g.vert_dict[DT25]=DT25 adjacent: ['DT24', 'DT26']
# g.vert_dict[DT26]=DT26 adjacent: ['DT25', 'DT27', 'CC10']
# g.vert_dict[DT27]=DT27 adjacent: ['DT26', 'DT28']
# g.vert_dict[DT28]=DT28 adjacent: ['DT27', 'DT29']
# g.vert_dict[DT29]=DT29 adjacent: ['DT28', 'DT30']
# g.vert_dict[DT30]=DT30 adjacent: ['DT29', 'DT31']
# g.vert_dict[DT31]=DT31 adjacent: ['DT30', 'DT32']
# g.vert_dict[DT32]=DT32 adjacent: ['DT31', 'DT33', 'EW2']
# g.vert_dict[DT33]=DT33 adjacent: ['DT32', 'DT34']
# g.vert_dict[DT34]=DT34 adjacent: ['DT33', 'DT35']
# g.vert_dict[DT35]=DT35 adjacent: ['DT34', 'CG1']
# g.vert_dict[EW1]=EW1 adjacent: ['EW2']
# g.vert_dict[EW2]=EW2 adjacent: ['EW1', 'EW3', 'DT32']
# g.vert_dict[EW3]=EW3 adjacent: ['EW2', 'EW4']
# g.vert_dict[EW4]=EW4 adjacent: ['EW3', 'EW5', 'CG0']
# g.vert_dict[EW5]=EW5 adjacent: ['EW4', 'EW6']
# g.vert_dict[EW6]=EW6 adjacent: ['EW5', 'EW7']
# g.vert_dict[EW7]=EW7 adjacent: ['EW6', 'EW8']
# g.vert_dict[EW8]=EW8 adjacent: ['EW7', 'EW9', 'CC9']
# g.vert_dict[EW9]=EW9 adjacent: ['EW8', 'EW10']
# g.vert_dict[EW10]=EW10 adjacent: ['EW9', 'EW11']
# g.vert_dict[EW11]=EW11 adjacent: ['EW10', 'EW12']
# g.vert_dict[EW12]=EW12 adjacent: ['EW11', 'EW13', 'DT14']
# g.vert_dict[EW13]=EW13 adjacent: ['EW12', 'EW14', 'NS25']
# g.vert_dict[EW14]=EW14 adjacent: ['EW13', 'EW15', 'NS26']
# g.vert_dict[EW15]=EW15 adjacent: ['EW14', 'EW16']
# g.vert_dict[EW16]=EW16 adjacent: ['EW15', 'EW17', 'NE3']
# g.vert_dict[EW17]=EW17 adjacent: ['EW16', 'EW18']
# g.vert_dict[EW18]=EW18 adjacent: ['EW17', 'EW19']
# g.vert_dict[EW19]=EW19 adjacent: ['EW18', 'EW20']
# g.vert_dict[EW20]=EW20 adjacent: ['EW19', 'EW21']
# g.vert_dict[EW21]=EW21 adjacent: ['EW20', 'EW22', 'CC22']
# g.vert_dict[EW22]=EW22 adjacent: ['EW21', 'EW23']
# g.vert_dict[EW23]=EW23 adjacent: ['EW22', 'EW24']
# g.vert_dict[EW24]=EW24 adjacent: ['EW23', 'EW25', 'NS1']
# g.vert_dict[EW25]=EW25 adjacent: ['EW24', 'EW26']
# g.vert_dict[EW26]=EW26 adjacent: ['EW25', 'EW27']
# g.vert_dict[EW27]=EW27 adjacent: ['EW26', 'EW28']
# g.vert_dict[EW28]=EW28 adjacent: ['EW27', 'EW29']
# g.vert_dict[EW29]=EW29 adjacent: ['EW28', 'EW30']
# g.vert_dict[EW30]=EW30 adjacent: ['EW29', 'EW31']
# g.vert_dict[EW31]=EW31 adjacent: ['EW30', 'EW32']
# g.vert_dict[EW32]=EW32 adjacent: ['EW31', 'EW33']
# g.vert_dict[EW33]=EW33 adjacent: ['EW32']
# g.vert_dict[CG1]=CG1 adjacent: ['CG0', 'CG2', 'DT35']
# g.vert_dict[CG2]=CG2 adjacent: ['CG1']
# g.vert_dict[CC1]=CC1 adjacent: ['CC2', 'NS24', 'NE6']
# g.vert_dict[CC2]=CC2 adjacent: ['CC1', 'CC3']
# g.vert_dict[CC3]=CC3 adjacent: ['CC2', 'CC4']
# g.vert_dict[CC4]=CC4 adjacent: ['CC3', 'CC5', 'DT15', 'CC34']
# g.vert_dict[CC5]=CC5 adjacent: ['CC4', 'CC6']
# g.vert_dict[CC6]=CC6 adjacent: ['CC5', 'CC7']
# g.vert_dict[CC7]=CC7 adjacent: ['CC6', 'CC8']
# g.vert_dict[CC8]=CC8 adjacent: ['CC7', 'CC9']
# g.vert_dict[CC9]=CC9 adjacent: ['CC8', 'CC10', 'EW8']
# g.vert_dict[CC10]=CC10 adjacent: ['CC9', 'CC11', 'DT26']
# g.vert_dict[CC11]=CC11 adjacent: ['CC10', 'CC12']
# g.vert_dict[CC12]=CC12 adjacent: ['CC11', 'CC13']
# g.vert_dict[CC13]=CC13 adjacent: ['CC12', 'CC14', 'NE12']
# g.vert_dict[CC14]=CC14 adjacent: ['CC13', 'CC15']
# g.vert_dict[CC15]=CC15 adjacent: ['CC14', 'CC16', 'NS17']
# g.vert_dict[CC16]=CC16 adjacent: ['CC15', 'CC17']
# g.vert_dict[CC17]=CC17 adjacent: ['CC16', 'CC18', 'TE9']
# g.vert_dict[CC18]=CC18 adjacent: ['CC17', 'CC19']
# g.vert_dict[CC19]=CC19 adjacent: ['CC18', 'CC20', 'DT9']
# g.vert_dict[CC20]=CC20 adjacent: ['CC19', 'CC21']
# g.vert_dict[CC21]=CC21 adjacent: ['CC20', 'CC22']
# g.vert_dict[CC22]=CC22 adjacent: ['CC21', 'CC23', 'EW21']
# g.vert_dict[CC23]=CC23 adjacent: ['CC22', 'CC24']
# g.vert_dict[CC24]=CC24 adjacent: ['CC23', 'CC25']
# g.vert_dict[CC25]=CC25 adjacent: ['CC24', 'CC26']
# g.vert_dict[CC26]=CC26 adjacent: ['CC25', 'CC27']
# g.vert_dict[CC27]=CC27 adjacent: ['CC26', 'CC28']
# g.vert_dict[CC28]=CC28 adjacent: ['CC27', 'CC29']
# g.vert_dict[CC29]=CC29 adjacent: ['CC28', 'NE1']
# g.vert_dict[CC33]=CC33 adjacent: ['CC34', 'NS27']
# g.vert_dict[CC34]=CC34 adjacent: ['CC33', 'CC4', 'DT16']
# g.vert_dict[NE1]=NE1 adjacent: ['NE2', 'CC29']
# g.vert_dict[NE2]=NE2 adjacent: ['NE1', 'NE3']
# g.vert_dict[NE3]=NE3 adjacent: ['NE2', 'NE4', 'EW16']
# g.vert_dict[NE4]=NE4 adjacent: ['NE3', 'NE5', 'DT19']
# g.vert_dict[NE5]=NE5 adjacent: ['NE4', 'NE6']
# g.vert_dict[NE6]=NE6 adjacent: ['NE5', 'NE7', 'NS24', 'CC1']
# g.vert_dict[NE7]=NE7 adjacent: ['NE6', 'NE8', 'DT12']
# g.vert_dict[NE8]=NE8 adjacent: ['NE7', 'NE9']
# g.vert_dict[NE9]=NE9 adjacent: ['NE8', 'NE10']
# g.vert_dict[NE10]=NE10 adjacent: ['NE9', 'NE11']
# g.vert_dict[NE11]=NE11 adjacent: ['NE10', 'NE12']
# g.vert_dict[NE12]=NE12 adjacent: ['NE11', 'NE13', 'CC13']
# g.vert_dict[NE13]=NE13 adjacent: ['NE12', 'NE14']
# g.vert_dict[NE14]=NE14 adjacent: ['NE13', 'NE15']
# g.vert_dict[NE15]=NE15 adjacent: ['NE14', 'NE16']
# g.vert_dict[NE16]=NE16 adjacent: ['NE15', 'NE17', 'SW8', 'SW1', 'SE1']
# g.vert_dict[NE17]=NE17 adjacent: ['NE16', 'PW7', 'PW1', 'PE7', 'PE1']
# g.vert_dict[BP1]=BP1 adjacent: ['BP2', 'NS4']
# g.vert_dict[BP2]=BP2 adjacent: ['BP1', 'BP3']
# g.vert_dict[BP3]=BP3 adjacent: ['BP2', 'BP4']
# g.vert_dict[BP4]=BP4 adjacent: ['BP3', 'BP5']
# g.vert_dict[BP5]=BP5 adjacent: ['BP4', 'BP6']
# g.vert_dict[BP6]=BP6 adjacent: ['BP5', 'BP7', 'DT1', 'BP13']
# g.vert_dict[BP7]=BP7 adjacent: ['BP6', 'BP8']
# g.vert_dict[BP8]=BP8 adjacent: ['BP7', 'BP9']
# g.vert_dict[BP9]=BP9 adjacent: ['BP8', 'BP10']
# g.vert_dict[BP10]=BP10 adjacent: ['BP9', 'BP11']
# g.vert_dict[BP11]=BP11 adjacent: ['BP10', 'BP12']
# g.vert_dict[BP12]=BP12 adjacent: ['BP11', 'BP13']
# g.vert_dict[BP13]=BP13 adjacent: ['BP12', 'BP6']
# g.vert_dict[SE1]=SE1 adjacent: ['SE2', 'NE16']
# g.vert_dict[SE2]=SE2 adjacent: ['SE1', 'SE3']
# g.vert_dict[SE3]=SE3 adjacent: ['SE2', 'SE4']
# g.vert_dict[SE4]=SE4 adjacent: ['SE3', 'SE5']
# g.vert_dict[SE5]=SE5 adjacent: ['SE4']
# g.vert_dict[SW1]=SW1 adjacent: ['SW2', 'NE16']
# g.vert_dict[SW2]=SW2 adjacent: ['SW1', 'SW3']
# g.vert_dict[SW3]=SW3 adjacent: ['SW2', 'SW4']
# g.vert_dict[SW4]=SW4 adjacent: ['SW3', 'SW5']
# g.vert_dict[SW5]=SW5 adjacent: ['SW4', 'SW6']
# g.vert_dict[SW6]=SW6 adjacent: ['SW5', 'SW7']
# g.vert_dict[SW7]=SW7 adjacent: ['SW6', 'SW8']
# g.vert_dict[SW8]=SW8 adjacent: ['SW7', 'NE16']
# g.vert_dict[PE1]=PE1 adjacent: ['PE2', 'NE17']
# g.vert_dict[PE2]=PE2 adjacent: ['PE1', 'PE3']
# g.vert_dict[PE3]=PE3 adjacent: ['PE2', 'PE4']
# g.vert_dict[PE4]=PE4 adjacent: ['PE3', 'PE5']
# g.vert_dict[PE5]=PE5 adjacent: ['PE4', 'PE6']
# g.vert_dict[PE6]=PE6 adjacent: ['PE5', 'PE7']
# g.vert_dict[PE7]=PE7 adjacent: ['PE6', 'NE17']
# g.vert_dict[PW1]=PW1 adjacent: ['PW2', 'NE17']
# g.vert_dict[PW2]=PW2 adjacent: ['PW1', 'PW3']
# g.vert_dict[PW3]=PW3 adjacent: ['PW2', 'PW4']
# g.vert_dict[PW4]=PW4 adjacent: ['PW3', 'PW5']
# g.vert_dict[PW5]=PW5 adjacent: ['PW4', 'PW6']
# g.vert_dict[PW6]=PW6 adjacent: ['PW5', 'PW7']
# g.vert_dict[PW7]=PW7 adjacent: ['PW6', 'NE17']
# g.vert_dict[CG0]=CG0 adjacent: ['CG1', 'EW4']

# %%
import heapq

def shortest(v, path):
    #''' make shortest path from v.previous'''
    if v.previous:
        path.append(v.previous.get_id())
        shortest(v.previous, path)
    return

def dijkstra(aGraph, start, target):
    print ('''Dijkstra's shortest path''')
    # Set the distance for the start node to zero 
    start.set_distance(0)
    
    # Put tuple pair into the priority queue
    unvisited_queue = [(v.get_distance(),v) for v in aGraph]
#     print(unvisited_queue[0])
#     print(unvisited_queue[0] <= unvisited_queue[1])
    heapq.heapify(unvisited_queue)

    while len(unvisited_queue):
        # Pops a vertex with the smallest distance 
        uv = heapq.heappop(unvisited_queue)
        current = uv[1]
        current.set_visited()

        #for next in v.adjacent:
        for next in current.adjacent:
            # if visited, skip
            if next.visited:
                continue
            new_dist = current.get_distance() + current.get_weight(next)
            
            if new_dist < next.get_distance():
                next.set_distance(new_dist)
                next.set_previous(current)
                print ('updated : current = %s next = %s new_dist = %s' \
                        %(current.get_id(), next.get_id(), next.get_distance()))
            else:
                print ('not updated : current = %s next = %s new_dist = %s' \
                        %(current.get_id(), next.get_id(), next.get_distance()))

        # Rebuild heap
        # 1. Pop every item
        while len(unvisited_queue):
            heapq.heappop(unvisited_queue)
        # 2. Put all vertices not visited into the queue
        unvisited_queue = [(v.get_distance(),v) for v in aGraph if not v.visited]
        heapq.heapify(unvisited_queue)
        
def get_total_weight(path, g):
    total = 0
    for vertexpos in range(len(path)-1):
        total += g.get_vertex(path[vertexpos]).get_weight(g.get_vertex(path[vertexpos+1]))
    return total

# %%
dijkstra(g, g.get_vertex('NE17'), g.get_vertex('NS8')) 

target = g.get_vertex('NS8')
path = [target.get_id()]
# print(path)
shortest(target, path)
print ('The shortest path : %s' %(path[::-1]))
print(get_total_weight(path, g))
# Out:
# Dijkstra's shortest path
# The shortest path : ['NE17', 'NE16', 'NE15', 'NE14', 'NE13', 'NE12', 'CC13', 'CC14', 'CC15', 'NS17', 'NS16', 'NS15', 'NS14', 'NS13', 'NS12', 'NS11', 'NS10', 'NS9', 'NS8']
# 46.0

# %%
## Generate 5000 random starting points from list of stations

def add_to_list_of_station(line_name, start, end, list_of_station):
    for i in range(start, end):
        list_of_station.append(line_name + str(i))
    return list_of_station

# Add NS Line
g = add_to_list_of_station("NS", 1, 28, g)
# Add TE Line
g = add_to_list_of_station("TE", 1, 9, g)
# Add DT Line
g = add_to_list_of_station("DT", 1, 35, g)
# Add EW Line
g = add_to_list_of_station("EW", 1, 33, g)
# Add EWEXT Line
g = add_to_list_of_station("CG", 1, 2, g)
# Add CC Line
g = add_to_list_of_station("CC", 1, 29, g)
# Add CC Line Ext
g = add_to_list_of_station("CC", 33, 34, g)
# Add NE Line
g = add_to_list_of_station("NE", 1, 17, g)

# Add BPLRT Line
g = add_to_list_of_station("BP", 1, 13, g)
# Add SKLRTE Line
g = add_to_list_of_station("SE", 1, 5, g)
# Add SKLRTW Line
g = add_to_list_of_station("SW", 1, 8, g)
# Add PLRTE Line
g = add_to_list_of_station("PE", 1, 7, g)
# Add PLRTW Line
g = add_to_list_of_station("PW", 1, 7, g)

# %%
import requests

apikey = ""
distance_matrix_header = "https://maps.googleapis.com/maps/api/distancematrix/json?"
directions_header = "https://maps.googleapis.com/maps/api/directions/json?"

def get_travel_time(origin, destination):
    origin_lat = origin[0]
    origin_long = origin[1]
    dest_lat = destination[0]
    dest_long = destination[1]
    
    url_header = directions_header
    start = "origin=" + str(origin_lat) + "%2C" + str(origin_long) + "&"
    end = "destination=" + str(dest_lat) + "%2C" + str(dest_long) + "&"
    mode = "mode=transit&"
    key = "key=" + apikey
    
    url_call = url_header + start + end + mode + key
    print(url_call)
    
    return url_call

# url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins=Boston%2CMA%7CCharlestown%2CMA&destinations=Lexington%2CMA%7CConcord%2CMA&departure_time=now&key=AIzaSyBcT5uYAL3aJ7oZFI0PNggHuRUPOrspTyA"

payload={}
headers = {}
origin = (1.323602059242882, 103.86798846088489)
destination = (1.4546421287927913, 103.7955653164353)


response = requests.request("GET", get_travel_time(origin, destination), headers=headers, data=payload)

print(response.text)

# %%
#Assuming the API Worked
#Things needed to be generated
#Dataframe of users transit stops

# Model all MRT stops as vertexes
